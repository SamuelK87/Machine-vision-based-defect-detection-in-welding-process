# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelK87/Machine-vision-based-defect-detection-in-welding-process/blob/master/Weld_def_10cls_small_VGGnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# USAGE
# python train.py --dataset dataset --model pokedex.model --labelbin lb.pickle

# set the matplotlib backend so figures can be saved in the background
import matplotlib

matplotlib.use("Agg")
import pandas as pd
# import the necessary packages
from keras.models import Sequential
from sklearn.metrics import classification_report
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras import backend as K
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
#from pyimagesearch.smallervggnet import SmallerVGGNet
import matplotlib.pyplot as plt
from imutils import paths
import numpy as np
import argparse
import random
import pickle
import cv2
import os

#######################################################################

class SmallerVGGNet:
	@staticmethod
	def build(width, height, depth, classes):
		# initialize the model along with the input shape to be
		# "channels last" and the channels dimension itself
		model = Sequential()
		inputShape = (height, width, depth)
		chanDim = -1

		# if we are using "channels first", update the input shape
		# and channels dimension
		if K.image_data_format() == "channels_first":
			inputShape = (depth, height, width)
			chanDim = 1

		# CONV => RELU => POOL
		model.add(Conv2D(32, (3, 3), padding="same",
			input_shape=inputShape))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(3, 3)))
		model.add(Dropout(0.25))

		# (CONV => RELU) * 2 => POOL
		model.add(Conv2D(64, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(Conv2D(64, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(2, 2)))
		model.add(Dropout(0.25))

		# (CONV => RELU) * 2 => POOL
		model.add(Conv2D(128, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(Conv2D(128, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(2, 2)))
		model.add(Dropout(0.25))

		# first (and only) set of FC => RELU layers
		model.add(Flatten())
		model.add(Dense(1024))
		model.add(Activation("relu"))
		model.add(BatchNormalization())
		model.add(Dropout(0.5))

		# softmax classifier
		model.add(Dense(classes))
		model.add(Activation("softmax"))

		# return the constructed network architecture
		return model


##############################################################################




# construct the argument parse and parse the arguments
#ap = argparse.ArgumentParser()
#ap.add_argument("-d", "--dataset", required=True,
#                help="path to input dataset (i.e., directory of images)")
#ap.add_argument("-m", "--model", required=True,
#                help="path to output model")
#ap.add_argument("-l", "--labelbin", required=True,
#                help="path to output label binarizer")
#ap.add_argument("-p", "--plot", type=str, default="plot.png",
#                help="path to output accuracy/loss plot")
#args = vars(ap.parse_args())

# initialize the number of epochs to train for, initial learning rate,
# batch size, and image dimensions
EPOCHS = 400
INIT_LR = 1e-3
BS = 32
IMAGE_DIMS = (96, 96, 3)

# initialize the data and labels
data = []
labels = []

# grab the image paths and randomly shuffle them
print("[INFO] loading images...")
imagePaths = sorted(list(paths.list_images('/content/drive/My Drive/Colab Notebooks/weld_dataset_10cls (1)')))
random.seed(42)
random.shuffle(imagePaths)

# loop over the input images
for imagePath in imagePaths:
    # load the image, pre-process it, and store it in the data list
    image = cv2.imread(imagePath)
    image = cv2.resize(image, (IMAGE_DIMS[1], IMAGE_DIMS[0]))
    image = img_to_array(image)
    data.append(image)

    # extract the class label from the image path and update the
    # labels list
    label = imagePath.split(os.path.sep)[-2]
    labels.append(label)

# scale the raw pixel intensities to the range [0, 1]
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)
print("[INFO] data matrix: {:.2f}MB".format(
    data.nbytes / (1024 * 1000.0)))

# binarize the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# partition the data into training and testing splits using 80% of
# the data for training and the remaining 20% for testing
(trainX, testX, trainY, testY) = train_test_split(data,
                                                  labels, test_size=0.2, random_state=42)

# account for skew in the labeled data
classTotals = trainY.sum(axis=0)
classWeight = classTotals.max() / classTotals

# construct the image generator for data augmentation
aug = ImageDataGenerator(rotation_range=False, width_shift_range=0.1,
                         height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
                         horizontal_flip=True, vertical_flip=True, fill_mode="nearest")

# initialize the model
print("[INFO] compiling model...")
model = SmallerVGGNet.build(width=IMAGE_DIMS[1], height=IMAGE_DIMS[0],
                            depth=IMAGE_DIMS[2], classes=len(lb.classes_))
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=opt,
              metrics=["accuracy"])

# checkpoint
filepath="/content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:{epoch:03d}-val_acc:{val_accuracy:.3f}.hdf5"
#filepath="/content/drive/My Drive/Colab Notebooks/Results/weld_def_10cls/best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor= 'val_accuracy' , verbose=1, save_best_only=True,
    mode= 'max' )
callbacks_list = [checkpoint]

# train the network
print("[INFO] training network...")
H = model.fit_generator(
    aug.flow(trainX, trainY, batch_size=BS),
    validation_data=(testX, testY),
    steps_per_epoch=len(trainX) // BS,
    epochs=EPOCHS,
    class_weight=classWeight, callbacks=callbacks_list,
    verbose=1)

# save the model to disk
print("[INFO] serializing network...")
model.save('/content/drive/My Drive/Colab Notebooks/Results/weld_def_10cls/Wld_10cls.model')

# save the label binarizer to disk
print("[INFO] serializing label binarizer...")
f = open('/content/drive/My Drive/Colab Notebooks/Results/weld_def_10cls/lb.pickle', "wb")
f.write(pickle.dumps(lb))
f.close()

# save the training history
# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(H.history)
hist_csv_file = '/content/drive/My Drive/Colab Notebooks/Results/weld_def_10cls/history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)


# make predictions on the testing set
print("[INFO] evaluating network...")
predIdxs = model.predict(testX, batch_size=BS)

# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
predIdxs = np.argmax(predIdxs, axis=1)

# show a nicely formatted classification report
print(classification_report(testY.argmax(axis=1), predIdxs,
	target_names=lb.classes_))



# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
N = EPOCHS
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper right")
plt.savefig('/content/drive/My Drive/Colab Notebooks/Results/weld_def_10cls/plot.png',dpi=300)
# Out:
# [INFO] loading images...
# [INFO] data matrix: 194.62MB
# [INFO] compiling model...
# [INFO] training network...
# Epoch 1/400
# 22/22 [==============================] - 4s 175ms/step - loss: 2.7770 - accuracy: 0.3765 - val_loss: 2.4818 - val_accuracy: 0.1215
#
# Epoch 00001: val_accuracy improved from -inf to 0.12155, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:001-val_acc:0.122.hdf5
# Epoch 2/400
# 22/22 [==============================] - 2s 108ms/step - loss: 1.7697 - accuracy: 0.4956 - val_loss: 2.8470 - val_accuracy: 0.1602
#
# Epoch 00002: val_accuracy improved from 0.12155 to 0.16022, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:002-val_acc:0.160.hdf5
# Epoch 3/400
# 22/22 [==============================] - 2s 112ms/step - loss: 1.3640 - accuracy: 0.5753 - val_loss: 3.2001 - val_accuracy: 0.1878
#
# Epoch 00003: val_accuracy improved from 0.16022 to 0.18785, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:003-val_acc:0.188.hdf5
# Epoch 4/400
# 22/22 [==============================] - 2s 107ms/step - loss: 1.3209 - accuracy: 0.6161 - val_loss: 3.9521 - val_accuracy: 0.1934
#
# Epoch 00004: val_accuracy improved from 0.18785 to 0.19337, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:004-val_acc:0.193.hdf5
# Epoch 5/400
# 22/22 [==============================] - 3s 138ms/step - loss: 1.2923 - accuracy: 0.5872 - val_loss: 3.6635 - val_accuracy: 0.2044
#
# Epoch 00005: val_accuracy improved from 0.19337 to 0.20442, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:005-val_acc:0.204.hdf5
# Epoch 6/400
# 22/22 [==============================] - 3s 120ms/step - loss: 1.1728 - accuracy: 0.6512 - val_loss: 6.1743 - val_accuracy: 0.1989
#
# Epoch 00006: val_accuracy did not improve from 0.20442
# Epoch 7/400
# 22/22 [==============================] - 2s 113ms/step - loss: 1.0916 - accuracy: 0.6860 - val_loss: 5.5821 - val_accuracy: 0.1878
#
# Epoch 00007: val_accuracy did not improve from 0.20442
# Epoch 8/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.9031 - accuracy: 0.7093 - val_loss: 6.6275 - val_accuracy: 0.1989
#
# Epoch 00008: val_accuracy did not improve from 0.20442
# Epoch 9/400
# 22/22 [==============================] - 3s 117ms/step - loss: 0.8907 - accuracy: 0.7088 - val_loss: 4.6007 - val_accuracy: 0.2376
#
# Epoch 00009: val_accuracy improved from 0.20442 to 0.23757, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:009-val_acc:0.238.hdf5
# Epoch 10/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.8703 - accuracy: 0.7078 - val_loss: 5.8484 - val_accuracy: 0.1657
#
# Epoch 00010: val_accuracy did not improve from 0.23757
# Epoch 11/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.6715 - accuracy: 0.7645 - val_loss: 7.3440 - val_accuracy: 0.2044
#
# Epoch 00011: val_accuracy did not improve from 0.23757
# Epoch 12/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.7669 - accuracy: 0.7366 - val_loss: 6.1060 - val_accuracy: 0.1602
#
# Epoch 00012: val_accuracy did not improve from 0.23757
# Epoch 13/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.7068 - accuracy: 0.7616 - val_loss: 6.5976 - val_accuracy: 0.1989
#
# Epoch 00013: val_accuracy did not improve from 0.23757
# Epoch 14/400
# 22/22 [==============================] - 3s 119ms/step - loss: 0.7206 - accuracy: 0.7599 - val_loss: 6.2825 - val_accuracy: 0.1602
#
# Epoch 00014: val_accuracy did not improve from 0.23757
# Epoch 15/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.6997 - accuracy: 0.7545 - val_loss: 4.7757 - val_accuracy: 0.2099
#
# Epoch 00015: val_accuracy did not improve from 0.23757
# Epoch 16/400
# 22/22 [==============================] - 2s 109ms/step - loss: 0.6986 - accuracy: 0.7718 - val_loss: 4.7776 - val_accuracy: 0.2210
#
# Epoch 00016: val_accuracy did not improve from 0.23757
# Epoch 17/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.5831 - accuracy: 0.7884 - val_loss: 4.0641 - val_accuracy: 0.3149
#
# Epoch 00017: val_accuracy improved from 0.23757 to 0.31492, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:017-val_acc:0.315.hdf5
# Epoch 18/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.5564 - accuracy: 0.8140 - val_loss: 2.2950 - val_accuracy: 0.4751
#
# Epoch 00018: val_accuracy improved from 0.31492 to 0.47514, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:018-val_acc:0.475.hdf5
# Epoch 19/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.5288 - accuracy: 0.8038 - val_loss: 4.3396 - val_accuracy: 0.2818
#
# Epoch 00019: val_accuracy did not improve from 0.47514
# Epoch 20/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.5066 - accuracy: 0.8154 - val_loss: 5.8961 - val_accuracy: 0.4199
#
# Epoch 00020: val_accuracy did not improve from 0.47514
# Epoch 21/400
# 22/22 [==============================] - 2s 109ms/step - loss: 0.4508 - accuracy: 0.8241 - val_loss: 3.2828 - val_accuracy: 0.5304
#
# Epoch 00021: val_accuracy improved from 0.47514 to 0.53039, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:021-val_acc:0.530.hdf5
# Epoch 22/400
# 22/22 [==============================] - 2s 112ms/step - loss: 0.4962 - accuracy: 0.8372 - val_loss: 2.0360 - val_accuracy: 0.6077
#
# Epoch 00022: val_accuracy improved from 0.53039 to 0.60773, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:022-val_acc:0.608.hdf5
# Epoch 23/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.4607 - accuracy: 0.8445 - val_loss: 5.4238 - val_accuracy: 0.3315
#
# Epoch 00023: val_accuracy did not improve from 0.60773
# Epoch 24/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.4166 - accuracy: 0.8576 - val_loss: 3.8973 - val_accuracy: 0.3039
#
# Epoch 00024: val_accuracy did not improve from 0.60773
# Epoch 25/400
# 22/22 [==============================] - 3s 124ms/step - loss: 0.4221 - accuracy: 0.8416 - val_loss: 3.0128 - val_accuracy: 0.5470
#
# Epoch 00025: val_accuracy did not improve from 0.60773
# Epoch 26/400
# 22/22 [==============================] - 3s 116ms/step - loss: 0.4080 - accuracy: 0.8565 - val_loss: 3.0209 - val_accuracy: 0.4365
#
# Epoch 00026: val_accuracy did not improve from 0.60773
# Epoch 27/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.4155 - accuracy: 0.8532 - val_loss: 5.8317 - val_accuracy: 0.2818
#
# Epoch 00027: val_accuracy did not improve from 0.60773
# Epoch 28/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.3562 - accuracy: 0.8839 - val_loss: 3.7793 - val_accuracy: 0.5580
#
# Epoch 00028: val_accuracy did not improve from 0.60773
# Epoch 29/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.3221 - accuracy: 0.8794 - val_loss: 2.9725 - val_accuracy: 0.4530
#
# Epoch 00029: val_accuracy did not improve from 0.60773
# Epoch 30/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.3423 - accuracy: 0.8808 - val_loss: 3.2842 - val_accuracy: 0.3536
#
# Epoch 00030: val_accuracy did not improve from 0.60773
# Epoch 31/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.3067 - accuracy: 0.8881 - val_loss: 4.0141 - val_accuracy: 0.4530
#
# Epoch 00031: val_accuracy did not improve from 0.60773
# Epoch 32/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.2515 - accuracy: 0.9215 - val_loss: 1.4352 - val_accuracy: 0.6464
#
# Epoch 00032: val_accuracy improved from 0.60773 to 0.64641, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:032-val_acc:0.646.hdf5
# Epoch 33/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.3100 - accuracy: 0.8866 - val_loss: 4.4969 - val_accuracy: 0.3867
#
# Epoch 00033: val_accuracy did not improve from 0.64641
# Epoch 34/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.2280 - accuracy: 0.9048 - val_loss: 0.8159 - val_accuracy: 0.7735
#
# Epoch 00034: val_accuracy improved from 0.64641 to 0.77348, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:034-val_acc:0.773.hdf5
# Epoch 35/400
# 22/22 [==============================] - 2s 99ms/step - loss: 0.3340 - accuracy: 0.8914 - val_loss: 2.1911 - val_accuracy: 0.6022
#
# Epoch 00035: val_accuracy did not improve from 0.77348
# Epoch 36/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.2677 - accuracy: 0.8939 - val_loss: 0.9171 - val_accuracy: 0.7017
#
# Epoch 00036: val_accuracy did not improve from 0.77348
# Epoch 37/400
# 22/22 [==============================] - 3s 121ms/step - loss: 0.2868 - accuracy: 0.8983 - val_loss: 1.0672 - val_accuracy: 0.7293
#
# Epoch 00037: val_accuracy did not improve from 0.77348
# Epoch 38/400
# 22/22 [==============================] - 3s 116ms/step - loss: 0.2274 - accuracy: 0.9162 - val_loss: 3.7766 - val_accuracy: 0.6133
#
# Epoch 00038: val_accuracy did not improve from 0.77348
# Epoch 39/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.3356 - accuracy: 0.8929 - val_loss: 4.4233 - val_accuracy: 0.3591
#
# Epoch 00039: val_accuracy did not improve from 0.77348
# Epoch 40/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.2821 - accuracy: 0.9006 - val_loss: 1.3813 - val_accuracy: 0.5746
#
# Epoch 00040: val_accuracy did not improve from 0.77348
# Epoch 41/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.4160 - accuracy: 0.8634 - val_loss: 1.9183 - val_accuracy: 0.5691
#
# Epoch 00041: val_accuracy did not improve from 0.77348
# Epoch 42/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.3764 - accuracy: 0.8808 - val_loss: 17.6693 - val_accuracy: 0.2155
#
# Epoch 00042: val_accuracy did not improve from 0.77348
# Epoch 43/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.4831 - accuracy: 0.8488 - val_loss: 9.9246 - val_accuracy: 0.2320
#
# Epoch 00043: val_accuracy did not improve from 0.77348
# Epoch 44/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.3998 - accuracy: 0.8663 - val_loss: 15.9998 - val_accuracy: 0.1934
#
# Epoch 00044: val_accuracy did not improve from 0.77348
# Epoch 45/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.4123 - accuracy: 0.8677 - val_loss: 8.0739 - val_accuracy: 0.2597
#
# Epoch 00045: val_accuracy did not improve from 0.77348
# Epoch 46/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.4110 - accuracy: 0.8706 - val_loss: 4.9937 - val_accuracy: 0.3812
#
# Epoch 00046: val_accuracy did not improve from 0.77348
# Epoch 47/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.3668 - accuracy: 0.8794 - val_loss: 6.3676 - val_accuracy: 0.2541
#
# Epoch 00047: val_accuracy did not improve from 0.77348
# Epoch 48/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.3414 - accuracy: 0.8706 - val_loss: 3.3502 - val_accuracy: 0.4033
#
# Epoch 00048: val_accuracy did not improve from 0.77348
# Epoch 49/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.2878 - accuracy: 0.8852 - val_loss: 3.1713 - val_accuracy: 0.5525
#
# Epoch 00049: val_accuracy did not improve from 0.77348
# Epoch 50/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.2392 - accuracy: 0.9113 - val_loss: 3.1113 - val_accuracy: 0.5249
#
# Epoch 00050: val_accuracy did not improve from 0.77348
# Epoch 51/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.2838 - accuracy: 0.8939 - val_loss: 4.9743 - val_accuracy: 0.4254
#
# Epoch 00051: val_accuracy did not improve from 0.77348
# Epoch 52/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.2332 - accuracy: 0.9055 - val_loss: 13.4438 - val_accuracy: 0.2597
#
# Epoch 00052: val_accuracy did not improve from 0.77348
# Epoch 53/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.2357 - accuracy: 0.9113 - val_loss: 5.5264 - val_accuracy: 0.4586
#
# Epoch 00053: val_accuracy did not improve from 0.77348
# Epoch 54/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.2428 - accuracy: 0.9247 - val_loss: 2.2657 - val_accuracy: 0.6133
#
# Epoch 00054: val_accuracy did not improve from 0.77348
# Epoch 55/400
# 22/22 [==============================] - 2s 101ms/step - loss: 0.2239 - accuracy: 0.9167 - val_loss: 2.3776 - val_accuracy: 0.6464
#
# Epoch 00055: val_accuracy did not improve from 0.77348
# Epoch 56/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.2228 - accuracy: 0.9244 - val_loss: 4.5208 - val_accuracy: 0.4309
#
# Epoch 00056: val_accuracy did not improve from 0.77348
# Epoch 57/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1800 - accuracy: 0.9332 - val_loss: 1.7410 - val_accuracy: 0.6961
#
# Epoch 00057: val_accuracy did not improve from 0.77348
# Epoch 58/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.2000 - accuracy: 0.9375 - val_loss: 2.5491 - val_accuracy: 0.6133
#
# Epoch 00058: val_accuracy did not improve from 0.77348
# Epoch 59/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.2955 - accuracy: 0.9018 - val_loss: 0.8419 - val_accuracy: 0.7680
#
# Epoch 00059: val_accuracy did not improve from 0.77348
# Epoch 60/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.3427 - accuracy: 0.8837 - val_loss: 1.5728 - val_accuracy: 0.6961
#
# Epoch 00060: val_accuracy did not improve from 0.77348
# Epoch 61/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.1991 - accuracy: 0.9247 - val_loss: 2.5317 - val_accuracy: 0.5414
#
# Epoch 00061: val_accuracy did not improve from 0.77348
# Epoch 62/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.2323 - accuracy: 0.9230 - val_loss: 5.0536 - val_accuracy: 0.5359
#
# Epoch 00062: val_accuracy did not improve from 0.77348
# Epoch 63/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.2029 - accuracy: 0.9259 - val_loss: 2.7141 - val_accuracy: 0.5856
#
# Epoch 00063: val_accuracy did not improve from 0.77348
# Epoch 64/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.2547 - accuracy: 0.9113 - val_loss: 2.8813 - val_accuracy: 0.5580
#
# Epoch 00064: val_accuracy did not improve from 0.77348
# Epoch 65/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1811 - accuracy: 0.9331 - val_loss: 1.7082 - val_accuracy: 0.6685
#
# Epoch 00065: val_accuracy did not improve from 0.77348
# Epoch 66/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.2607 - accuracy: 0.9157 - val_loss: 3.0871 - val_accuracy: 0.5414
#
# Epoch 00066: val_accuracy did not improve from 0.77348
# Epoch 67/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.2568 - accuracy: 0.9172 - val_loss: 1.5151 - val_accuracy: 0.7072
#
# Epoch 00067: val_accuracy did not improve from 0.77348
# Epoch 68/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.2453 - accuracy: 0.9244 - val_loss: 3.8749 - val_accuracy: 0.4807
#
# Epoch 00068: val_accuracy did not improve from 0.77348
# Epoch 69/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1393 - accuracy: 0.9535 - val_loss: 0.4558 - val_accuracy: 0.8343
#
# Epoch 00069: val_accuracy improved from 0.77348 to 0.83425, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:069-val_acc:0.834.hdf5
# Epoch 70/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1980 - accuracy: 0.9302 - val_loss: 0.6136 - val_accuracy: 0.8011
#
# Epoch 00070: val_accuracy did not improve from 0.83425
# Epoch 71/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.1776 - accuracy: 0.9433 - val_loss: 2.9844 - val_accuracy: 0.5193
#
# Epoch 00071: val_accuracy did not improve from 0.83425
# Epoch 72/400
# 22/22 [==============================] - 2s 110ms/step - loss: 0.1388 - accuracy: 0.9531 - val_loss: 2.3940 - val_accuracy: 0.5304
#
# Epoch 00072: val_accuracy did not improve from 0.83425
# Epoch 73/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1656 - accuracy: 0.9345 - val_loss: 1.4938 - val_accuracy: 0.6796
#
# Epoch 00073: val_accuracy did not improve from 0.83425
# Epoch 74/400
# 22/22 [==============================] - 3s 116ms/step - loss: 0.1594 - accuracy: 0.9477 - val_loss: 1.2033 - val_accuracy: 0.7735
#
# Epoch 00074: val_accuracy did not improve from 0.83425
# Epoch 75/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1923 - accuracy: 0.9360 - val_loss: 0.6979 - val_accuracy: 0.7901
#
# Epoch 00075: val_accuracy did not improve from 0.83425
# Epoch 76/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.1279 - accuracy: 0.9535 - val_loss: 2.8214 - val_accuracy: 0.5470
#
# Epoch 00076: val_accuracy did not improve from 0.83425
# Epoch 77/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.1429 - accuracy: 0.9517 - val_loss: 0.8876 - val_accuracy: 0.7403
#
# Epoch 00077: val_accuracy did not improve from 0.83425
# Epoch 78/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1648 - accuracy: 0.9390 - val_loss: 3.8799 - val_accuracy: 0.5801
#
# Epoch 00078: val_accuracy did not improve from 0.83425
# Epoch 79/400
# 22/22 [==============================] - 2s 110ms/step - loss: 0.1340 - accuracy: 0.9474 - val_loss: 1.1154 - val_accuracy: 0.8122
#
# Epoch 00079: val_accuracy did not improve from 0.83425
# Epoch 80/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1593 - accuracy: 0.9477 - val_loss: 0.9611 - val_accuracy: 0.7569
#
# Epoch 00080: val_accuracy did not improve from 0.83425
# Epoch 81/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.1497 - accuracy: 0.9477 - val_loss: 10.7489 - val_accuracy: 0.3370
#
# Epoch 00081: val_accuracy did not improve from 0.83425
# Epoch 82/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.2110 - accuracy: 0.9331 - val_loss: 1.1642 - val_accuracy: 0.7624
#
# Epoch 00082: val_accuracy did not improve from 0.83425
# Epoch 83/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.1050 - accuracy: 0.9666 - val_loss: 2.9225 - val_accuracy: 0.4917
#
# Epoch 00083: val_accuracy did not improve from 0.83425
# Epoch 84/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1134 - accuracy: 0.9578 - val_loss: 0.5155 - val_accuracy: 0.8785
#
# Epoch 00084: val_accuracy improved from 0.83425 to 0.87845, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:084-val_acc:0.878.hdf5
# Epoch 85/400
# 22/22 [==============================] - 2s 101ms/step - loss: 0.1330 - accuracy: 0.9520 - val_loss: 3.2822 - val_accuracy: 0.4033
#
# Epoch 00085: val_accuracy did not improve from 0.87845
# Epoch 86/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.2195 - accuracy: 0.9317 - val_loss: 7.6123 - val_accuracy: 0.2541
#
# Epoch 00086: val_accuracy did not improve from 0.87845
# Epoch 87/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.1851 - accuracy: 0.9404 - val_loss: 5.1759 - val_accuracy: 0.4696
#
# Epoch 00087: val_accuracy did not improve from 0.87845
# Epoch 88/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.1927 - accuracy: 0.9360 - val_loss: 1.8861 - val_accuracy: 0.6796
#
# Epoch 00088: val_accuracy did not improve from 0.87845
# Epoch 89/400
# 22/22 [==============================] - 3s 115ms/step - loss: 0.1600 - accuracy: 0.9520 - val_loss: 1.4306 - val_accuracy: 0.6740
#
# Epoch 00089: val_accuracy did not improve from 0.87845
# Epoch 90/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1230 - accuracy: 0.9637 - val_loss: 4.5250 - val_accuracy: 0.4420
#
# Epoch 00090: val_accuracy did not improve from 0.87845
# Epoch 91/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.1299 - accuracy: 0.9477 - val_loss: 7.1234 - val_accuracy: 0.3978
#
# Epoch 00091: val_accuracy did not improve from 0.87845
# Epoch 92/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1693 - accuracy: 0.9404 - val_loss: 6.4034 - val_accuracy: 0.4420
#
# Epoch 00092: val_accuracy did not improve from 0.87845
# Epoch 93/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.2040 - accuracy: 0.9404 - val_loss: 7.1273 - val_accuracy: 0.2376
#
# Epoch 00093: val_accuracy did not improve from 0.87845
# Epoch 94/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.1265 - accuracy: 0.9549 - val_loss: 5.7275 - val_accuracy: 0.4365
#
# Epoch 00094: val_accuracy did not improve from 0.87845
# Epoch 95/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.1075 - accuracy: 0.9637 - val_loss: 2.3938 - val_accuracy: 0.6133
#
# Epoch 00095: val_accuracy did not improve from 0.87845
# Epoch 96/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0960 - accuracy: 0.9673 - val_loss: 0.6834 - val_accuracy: 0.8122
#
# Epoch 00096: val_accuracy did not improve from 0.87845
# Epoch 97/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1032 - accuracy: 0.9613 - val_loss: 4.7659 - val_accuracy: 0.4696
#
# Epoch 00097: val_accuracy did not improve from 0.87845
# Epoch 98/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.1497 - accuracy: 0.9462 - val_loss: 3.4242 - val_accuracy: 0.6464
#
# Epoch 00098: val_accuracy did not improve from 0.87845
# Epoch 99/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.1360 - accuracy: 0.9574 - val_loss: 4.1894 - val_accuracy: 0.4807
#
# Epoch 00099: val_accuracy did not improve from 0.87845
# Epoch 100/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1371 - accuracy: 0.9524 - val_loss: 0.8596 - val_accuracy: 0.8453
#
# Epoch 00100: val_accuracy did not improve from 0.87845
# Epoch 101/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.1392 - accuracy: 0.9545 - val_loss: 1.7769 - val_accuracy: 0.7182
#
# Epoch 00101: val_accuracy did not improve from 0.87845
# Epoch 102/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.1062 - accuracy: 0.9593 - val_loss: 2.6512 - val_accuracy: 0.5746
#
# Epoch 00102: val_accuracy did not improve from 0.87845
# Epoch 103/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1019 - accuracy: 0.9695 - val_loss: 2.2719 - val_accuracy: 0.6851
#
# Epoch 00103: val_accuracy did not improve from 0.87845
# Epoch 104/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0752 - accuracy: 0.9637 - val_loss: 0.8582 - val_accuracy: 0.8011
#
# Epoch 00104: val_accuracy did not improve from 0.87845
# Epoch 105/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1267 - accuracy: 0.9643 - val_loss: 1.3964 - val_accuracy: 0.7624
#
# Epoch 00105: val_accuracy did not improve from 0.87845
# Epoch 106/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0889 - accuracy: 0.9688 - val_loss: 1.1718 - val_accuracy: 0.7459
#
# Epoch 00106: val_accuracy did not improve from 0.87845
# Epoch 107/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0674 - accuracy: 0.9797 - val_loss: 1.1615 - val_accuracy: 0.7459
#
# Epoch 00107: val_accuracy did not improve from 0.87845
# Epoch 108/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0837 - accuracy: 0.9680 - val_loss: 4.5288 - val_accuracy: 0.4088
#
# Epoch 00108: val_accuracy did not improve from 0.87845
# Epoch 109/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0936 - accuracy: 0.9724 - val_loss: 0.7368 - val_accuracy: 0.8066
#
# Epoch 00109: val_accuracy did not improve from 0.87845
# Epoch 110/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.0818 - accuracy: 0.9762 - val_loss: 10.2796 - val_accuracy: 0.3039
#
# Epoch 00110: val_accuracy did not improve from 0.87845
# Epoch 111/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.2078 - accuracy: 0.9347 - val_loss: 4.8824 - val_accuracy: 0.4917
#
# Epoch 00111: val_accuracy did not improve from 0.87845
# Epoch 112/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.1191 - accuracy: 0.9593 - val_loss: 1.7797 - val_accuracy: 0.7293
#
# Epoch 00112: val_accuracy did not improve from 0.87845
# Epoch 113/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.1194 - accuracy: 0.9724 - val_loss: 0.7617 - val_accuracy: 0.7790
#
# Epoch 00113: val_accuracy did not improve from 0.87845
# Epoch 114/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0601 - accuracy: 0.9797 - val_loss: 3.2012 - val_accuracy: 0.5414
#
# Epoch 00114: val_accuracy did not improve from 0.87845
# Epoch 115/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1199 - accuracy: 0.9520 - val_loss: 0.4683 - val_accuracy: 0.8840
#
# Epoch 00115: val_accuracy improved from 0.87845 to 0.88398, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:115-val_acc:0.884.hdf5
# Epoch 116/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.1101 - accuracy: 0.9659 - val_loss: 1.2118 - val_accuracy: 0.7680
#
# Epoch 00116: val_accuracy did not improve from 0.88398
# Epoch 117/400
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0768 - accuracy: 0.9717 - val_loss: 2.4029 - val_accuracy: 0.6519
#
# Epoch 00117: val_accuracy did not improve from 0.88398
# Epoch 118/400
# 22/22 [==============================] - 2s 111ms/step - loss: 0.0713 - accuracy: 0.9738 - val_loss: 5.8478 - val_accuracy: 0.4641
#
# Epoch 00118: val_accuracy did not improve from 0.88398
# Epoch 119/400
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0587 - accuracy: 0.9767 - val_loss: 2.5032 - val_accuracy: 0.6796
#
# Epoch 00119: val_accuracy did not improve from 0.88398
# Epoch 120/400
# 22/22 [==============================] - 3s 117ms/step - loss: 0.1277 - accuracy: 0.9651 - val_loss: 1.1024 - val_accuracy: 0.7624
#
# Epoch 00120: val_accuracy did not improve from 0.88398
# Epoch 121/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0536 - accuracy: 0.9815 - val_loss: 2.9352 - val_accuracy: 0.4254
#
# Epoch 00121: val_accuracy did not improve from 0.88398
# Epoch 122/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0727 - accuracy: 0.9826 - val_loss: 7.3713 - val_accuracy: 0.3978
#
# Epoch 00122: val_accuracy did not improve from 0.88398
# Epoch 123/400
# 22/22 [==============================] - 2s 101ms/step - loss: 0.1033 - accuracy: 0.9673 - val_loss: 1.2264 - val_accuracy: 0.7735
#
# Epoch 00123: val_accuracy did not improve from 0.88398
# Epoch 124/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0943 - accuracy: 0.9622 - val_loss: 2.2997 - val_accuracy: 0.7127
#
# Epoch 00124: val_accuracy did not improve from 0.88398
# Epoch 125/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.0892 - accuracy: 0.9724 - val_loss: 5.8668 - val_accuracy: 0.4033
#
# Epoch 00125: val_accuracy did not improve from 0.88398
# Epoch 126/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0668 - accuracy: 0.9826 - val_loss: 0.3840 - val_accuracy: 0.9227
#
# Epoch 00126: val_accuracy improved from 0.88398 to 0.92265, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:126-val_acc:0.923.hdf5
# Epoch 127/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1153 - accuracy: 0.9608 - val_loss: 1.2071 - val_accuracy: 0.8232
#
# Epoch 00127: val_accuracy did not improve from 0.92265
# Epoch 128/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0918 - accuracy: 0.9666 - val_loss: 3.5696 - val_accuracy: 0.4144
#
# Epoch 00128: val_accuracy did not improve from 0.92265
# Epoch 129/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0831 - accuracy: 0.9730 - val_loss: 1.8297 - val_accuracy: 0.6575
#
# Epoch 00129: val_accuracy did not improve from 0.92265
# Epoch 130/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1201 - accuracy: 0.9535 - val_loss: 0.6209 - val_accuracy: 0.8674
#
# Epoch 00130: val_accuracy did not improve from 0.92265
# Epoch 131/400
# 22/22 [==============================] - 3s 115ms/step - loss: 0.1331 - accuracy: 0.9462 - val_loss: 5.8372 - val_accuracy: 0.4862
#
# Epoch 00131: val_accuracy did not improve from 0.92265
# Epoch 132/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0930 - accuracy: 0.9709 - val_loss: 4.0952 - val_accuracy: 0.6464
#
# Epoch 00132: val_accuracy did not improve from 0.92265
# Epoch 133/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1362 - accuracy: 0.9608 - val_loss: 1.1469 - val_accuracy: 0.7569
#
# Epoch 00133: val_accuracy did not improve from 0.92265
# Epoch 134/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.0591 - accuracy: 0.9797 - val_loss: 3.3931 - val_accuracy: 0.5635
#
# Epoch 00134: val_accuracy did not improve from 0.92265
# Epoch 135/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.0801 - accuracy: 0.9695 - val_loss: 0.2504 - val_accuracy: 0.9171
#
# Epoch 00135: val_accuracy did not improve from 0.92265
# Epoch 136/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1048 - accuracy: 0.9637 - val_loss: 5.1250 - val_accuracy: 0.5249
#
# Epoch 00136: val_accuracy did not improve from 0.92265
# Epoch 137/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1153 - accuracy: 0.9666 - val_loss: 6.4135 - val_accuracy: 0.3370
#
# Epoch 00137: val_accuracy did not improve from 0.92265
# Epoch 138/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1033 - accuracy: 0.9637 - val_loss: 3.9030 - val_accuracy: 0.2486
#
# Epoch 00138: val_accuracy did not improve from 0.92265
# Epoch 139/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1039 - accuracy: 0.9709 - val_loss: 5.2560 - val_accuracy: 0.2486
#
# Epoch 00139: val_accuracy did not improve from 0.92265
# Epoch 140/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.1338 - accuracy: 0.9578 - val_loss: 1.4621 - val_accuracy: 0.7901
#
# Epoch 00140: val_accuracy did not improve from 0.92265
# Epoch 141/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.1046 - accuracy: 0.9549 - val_loss: 3.0216 - val_accuracy: 0.5028
#
# Epoch 00141: val_accuracy did not improve from 0.92265
# Epoch 142/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0683 - accuracy: 0.9767 - val_loss: 5.9865 - val_accuracy: 0.5470
#
# Epoch 00142: val_accuracy did not improve from 0.92265
# Epoch 143/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.1114 - accuracy: 0.9688 - val_loss: 4.9420 - val_accuracy: 0.4751
#
# Epoch 00143: val_accuracy did not improve from 0.92265
# Epoch 144/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.0994 - accuracy: 0.9658 - val_loss: 1.2060 - val_accuracy: 0.7790
#
# Epoch 00144: val_accuracy did not improve from 0.92265
# Epoch 145/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0788 - accuracy: 0.9709 - val_loss: 1.1308 - val_accuracy: 0.8122
#
# Epoch 00145: val_accuracy did not improve from 0.92265
# Epoch 146/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0590 - accuracy: 0.9811 - val_loss: 1.8553 - val_accuracy: 0.7127
#
# Epoch 00146: val_accuracy did not improve from 0.92265
# Epoch 147/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0970 - accuracy: 0.9753 - val_loss: 7.5041 - val_accuracy: 0.3591
#
# Epoch 00147: val_accuracy did not improve from 0.92265
# Epoch 148/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.1032 - accuracy: 0.9651 - val_loss: 11.4658 - val_accuracy: 0.2541
#
# Epoch 00148: val_accuracy did not improve from 0.92265
# Epoch 149/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0806 - accuracy: 0.9753 - val_loss: 4.7140 - val_accuracy: 0.5359
#
# Epoch 00149: val_accuracy did not improve from 0.92265
# Epoch 150/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0752 - accuracy: 0.9744 - val_loss: 1.6864 - val_accuracy: 0.7514
#
# Epoch 00150: val_accuracy did not improve from 0.92265
# Epoch 151/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0592 - accuracy: 0.9797 - val_loss: 2.6814 - val_accuracy: 0.6133
#
# Epoch 00151: val_accuracy did not improve from 0.92265
# Epoch 152/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0840 - accuracy: 0.9680 - val_loss: 0.7374 - val_accuracy: 0.8398
#
# Epoch 00152: val_accuracy did not improve from 0.92265
# Epoch 153/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0683 - accuracy: 0.9777 - val_loss: 7.5254 - val_accuracy: 0.3867
#
# Epoch 00153: val_accuracy did not improve from 0.92265
# Epoch 154/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0568 - accuracy: 0.9787 - val_loss: 2.5033 - val_accuracy: 0.6077
#
# Epoch 00154: val_accuracy did not improve from 0.92265
# Epoch 155/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0962 - accuracy: 0.9709 - val_loss: 0.2301 - val_accuracy: 0.9392
#
# Epoch 00155: val_accuracy improved from 0.92265 to 0.93923, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:155-val_acc:0.939.hdf5
# Epoch 156/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1291 - accuracy: 0.9680 - val_loss: 12.1034 - val_accuracy: 0.3094
#
# Epoch 00156: val_accuracy did not improve from 0.93923
# Epoch 157/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0984 - accuracy: 0.9717 - val_loss: 0.5733 - val_accuracy: 0.8453
#
# Epoch 00157: val_accuracy did not improve from 0.93923
# Epoch 158/400
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0794 - accuracy: 0.9787 - val_loss: 0.5880 - val_accuracy: 0.8840
#
# Epoch 00158: val_accuracy did not improve from 0.93923
# Epoch 159/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0846 - accuracy: 0.9767 - val_loss: 0.5030 - val_accuracy: 0.8398
#
# Epoch 00159: val_accuracy did not improve from 0.93923
# Epoch 160/400
# 22/22 [==============================] - 3s 117ms/step - loss: 0.0466 - accuracy: 0.9884 - val_loss: 0.1794 - val_accuracy: 0.9503
#
# Epoch 00160: val_accuracy improved from 0.93923 to 0.95028, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:160-val_acc:0.950.hdf5
# Epoch 161/400
# 22/22 [==============================] - 2s 101ms/step - loss: 0.0829 - accuracy: 0.9767 - val_loss: 5.3081 - val_accuracy: 0.3094
#
# Epoch 00161: val_accuracy did not improve from 0.95028
# Epoch 162/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0792 - accuracy: 0.9753 - val_loss: 5.5409 - val_accuracy: 0.4696
#
# Epoch 00162: val_accuracy did not improve from 0.95028
# Epoch 163/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0434 - accuracy: 0.9869 - val_loss: 10.7213 - val_accuracy: 0.2983
#
# Epoch 00163: val_accuracy did not improve from 0.95028
# Epoch 164/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0464 - accuracy: 0.9840 - val_loss: 0.3968 - val_accuracy: 0.9061
#
# Epoch 00164: val_accuracy did not improve from 0.95028
# Epoch 165/400
# 22/22 [==============================] - 3s 117ms/step - loss: 0.0399 - accuracy: 0.9884 - val_loss: 2.0155 - val_accuracy: 0.7624
#
# Epoch 00165: val_accuracy did not improve from 0.95028
# Epoch 166/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0475 - accuracy: 0.9884 - val_loss: 0.2255 - val_accuracy: 0.9558
#
# Epoch 00166: val_accuracy improved from 0.95028 to 0.95580, saving model to /content/drive/My Drive/Colab Notebooks/Results/checkpoint/epochs:166-val_acc:0.956.hdf5
# Epoch 167/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0600 - accuracy: 0.9840 - val_loss: 2.5546 - val_accuracy: 0.6575
#
# Epoch 00167: val_accuracy did not improve from 0.95580
# Epoch 168/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0491 - accuracy: 0.9869 - val_loss: 3.5513 - val_accuracy: 0.5746
#
# Epoch 00168: val_accuracy did not improve from 0.95580
# Epoch 169/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0819 - accuracy: 0.9738 - val_loss: 1.5736 - val_accuracy: 0.7348
#
# Epoch 00169: val_accuracy did not improve from 0.95580
# Epoch 170/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0581 - accuracy: 0.9797 - val_loss: 1.1723 - val_accuracy: 0.7624
#
# Epoch 00170: val_accuracy did not improve from 0.95580
# Epoch 171/400
# 22/22 [==============================] - 3s 118ms/step - loss: 0.0327 - accuracy: 0.9901 - val_loss: 1.1512 - val_accuracy: 0.8011
#
# Epoch 00171: val_accuracy did not improve from 0.95580
# Epoch 172/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0759 - accuracy: 0.9777 - val_loss: 0.7545 - val_accuracy: 0.8177
#
# Epoch 00172: val_accuracy did not improve from 0.95580
# Epoch 173/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0644 - accuracy: 0.9782 - val_loss: 5.9874 - val_accuracy: 0.4088
#
# Epoch 00173: val_accuracy did not improve from 0.95580
# Epoch 174/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1220 - accuracy: 0.9753 - val_loss: 0.6327 - val_accuracy: 0.8232
#
# Epoch 00174: val_accuracy did not improve from 0.95580
# Epoch 175/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0221 - accuracy: 0.9901 - val_loss: 0.7410 - val_accuracy: 0.8398
#
# Epoch 00175: val_accuracy did not improve from 0.95580
# Epoch 176/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.0423 - accuracy: 0.9881 - val_loss: 0.7400 - val_accuracy: 0.8840
#
# Epoch 00176: val_accuracy did not improve from 0.95580
# Epoch 177/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0352 - accuracy: 0.9915 - val_loss: 2.6001 - val_accuracy: 0.5249
#
# Epoch 00177: val_accuracy did not improve from 0.95580
# Epoch 178/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0227 - accuracy: 0.9898 - val_loss: 0.4332 - val_accuracy: 0.9227
#
# Epoch 00178: val_accuracy did not improve from 0.95580
# Epoch 179/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0455 - accuracy: 0.9840 - val_loss: 3.5731 - val_accuracy: 0.5525
#
# Epoch 00179: val_accuracy did not improve from 0.95580
# Epoch 180/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0745 - accuracy: 0.9695 - val_loss: 4.2391 - val_accuracy: 0.5359
#
# Epoch 00180: val_accuracy did not improve from 0.95580
# Epoch 181/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0441 - accuracy: 0.9869 - val_loss: 3.2847 - val_accuracy: 0.5580
#
# Epoch 00181: val_accuracy did not improve from 0.95580
# Epoch 182/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1136 - accuracy: 0.9637 - val_loss: 4.4289 - val_accuracy: 0.4088
#
# Epoch 00182: val_accuracy did not improve from 0.95580
# Epoch 183/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1471 - accuracy: 0.9578 - val_loss: 5.9207 - val_accuracy: 0.2155
#
# Epoch 00183: val_accuracy did not improve from 0.95580
# Epoch 184/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1058 - accuracy: 0.9666 - val_loss: 0.5800 - val_accuracy: 0.8950
#
# Epoch 00184: val_accuracy did not improve from 0.95580
# Epoch 185/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.1037 - accuracy: 0.9651 - val_loss: 8.9750 - val_accuracy: 0.1492
#
# Epoch 00185: val_accuracy did not improve from 0.95580
# Epoch 186/400
# 22/22 [==============================] - 2s 109ms/step - loss: 0.1933 - accuracy: 0.9375 - val_loss: 10.6212 - val_accuracy: 0.1934
#
# Epoch 00186: val_accuracy did not improve from 0.95580
# Epoch 187/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0754 - accuracy: 0.9753 - val_loss: 9.4370 - val_accuracy: 0.1989
#
# Epoch 00187: val_accuracy did not improve from 0.95580
# Epoch 188/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1442 - accuracy: 0.9651 - val_loss: 2.4009 - val_accuracy: 0.6354
#
# Epoch 00188: val_accuracy did not improve from 0.95580
# Epoch 189/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1221 - accuracy: 0.9549 - val_loss: 3.8480 - val_accuracy: 0.5359
#
# Epoch 00189: val_accuracy did not improve from 0.95580
# Epoch 190/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.1160 - accuracy: 0.9631 - val_loss: 2.8260 - val_accuracy: 0.6188
#
# Epoch 00190: val_accuracy did not improve from 0.95580
# Epoch 191/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1740 - accuracy: 0.9554 - val_loss: 13.7641 - val_accuracy: 0.2044
#
# Epoch 00191: val_accuracy did not improve from 0.95580
# Epoch 192/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.1486 - accuracy: 0.9520 - val_loss: 7.7603 - val_accuracy: 0.3481
#
# Epoch 00192: val_accuracy did not improve from 0.95580
# Epoch 193/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.1193 - accuracy: 0.9659 - val_loss: 5.5162 - val_accuracy: 0.6022
#
# Epoch 00193: val_accuracy did not improve from 0.95580
# Epoch 194/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1161 - accuracy: 0.9628 - val_loss: 11.5473 - val_accuracy: 0.1989
#
# Epoch 00194: val_accuracy did not improve from 0.95580
# Epoch 195/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0623 - accuracy: 0.9801 - val_loss: 4.5639 - val_accuracy: 0.5691
#
# Epoch 00195: val_accuracy did not improve from 0.95580
# Epoch 196/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0939 - accuracy: 0.9608 - val_loss: 1.4375 - val_accuracy: 0.8066
#
# Epoch 00196: val_accuracy did not improve from 0.95580
# Epoch 197/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1148 - accuracy: 0.9666 - val_loss: 1.7889 - val_accuracy: 0.6630
#
# Epoch 00197: val_accuracy did not improve from 0.95580
# Epoch 198/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1313 - accuracy: 0.9539 - val_loss: 4.4392 - val_accuracy: 0.4420
#
# Epoch 00198: val_accuracy did not improve from 0.95580
# Epoch 199/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0727 - accuracy: 0.9797 - val_loss: 1.8323 - val_accuracy: 0.6243
#
# Epoch 00199: val_accuracy did not improve from 0.95580
# Epoch 200/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0603 - accuracy: 0.9787 - val_loss: 3.4972 - val_accuracy: 0.4199
#
# Epoch 00200: val_accuracy did not improve from 0.95580
# Epoch 201/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0760 - accuracy: 0.9762 - val_loss: 2.8228 - val_accuracy: 0.6133
#
# Epoch 00201: val_accuracy did not improve from 0.95580
# Epoch 202/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0577 - accuracy: 0.9858 - val_loss: 5.1937 - val_accuracy: 0.4365
#
# Epoch 00202: val_accuracy did not improve from 0.95580
# Epoch 203/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0812 - accuracy: 0.9724 - val_loss: 2.0349 - val_accuracy: 0.6630
#
# Epoch 00203: val_accuracy did not improve from 0.95580
# Epoch 204/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0989 - accuracy: 0.9753 - val_loss: 1.8585 - val_accuracy: 0.6906
#
# Epoch 00204: val_accuracy did not improve from 0.95580
# Epoch 205/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0964 - accuracy: 0.9738 - val_loss: 1.0430 - val_accuracy: 0.8177
#
# Epoch 00205: val_accuracy did not improve from 0.95580
# Epoch 206/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0487 - accuracy: 0.9869 - val_loss: 3.2446 - val_accuracy: 0.5635
#
# Epoch 00206: val_accuracy did not improve from 0.95580
# Epoch 207/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0480 - accuracy: 0.9855 - val_loss: 0.6339 - val_accuracy: 0.8453
#
# Epoch 00207: val_accuracy did not improve from 0.95580
# Epoch 208/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0618 - accuracy: 0.9797 - val_loss: 1.5732 - val_accuracy: 0.7127
#
# Epoch 00208: val_accuracy did not improve from 0.95580
# Epoch 209/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0387 - accuracy: 0.9826 - val_loss: 0.4002 - val_accuracy: 0.8895
#
# Epoch 00209: val_accuracy did not improve from 0.95580
# Epoch 210/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0566 - accuracy: 0.9811 - val_loss: 1.0169 - val_accuracy: 0.8011
#
# Epoch 00210: val_accuracy did not improve from 0.95580
# Epoch 211/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0691 - accuracy: 0.9811 - val_loss: 4.5908 - val_accuracy: 0.4862
#
# Epoch 00211: val_accuracy did not improve from 0.95580
# Epoch 212/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0269 - accuracy: 0.9929 - val_loss: 2.0443 - val_accuracy: 0.6630
#
# Epoch 00212: val_accuracy did not improve from 0.95580
# Epoch 213/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.0316 - accuracy: 0.9911 - val_loss: 0.3684 - val_accuracy: 0.9006
#
# Epoch 00213: val_accuracy did not improve from 0.95580
# Epoch 214/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0558 - accuracy: 0.9815 - val_loss: 8.9936 - val_accuracy: 0.4309
#
# Epoch 00214: val_accuracy did not improve from 0.95580
# Epoch 215/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0718 - accuracy: 0.9767 - val_loss: 6.0431 - val_accuracy: 0.4586
#
# Epoch 00215: val_accuracy did not improve from 0.95580
# Epoch 216/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0739 - accuracy: 0.9826 - val_loss: 0.8869 - val_accuracy: 0.7901
#
# Epoch 00216: val_accuracy did not improve from 0.95580
# Epoch 217/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1017 - accuracy: 0.9666 - val_loss: 0.8994 - val_accuracy: 0.8066
#
# Epoch 00217: val_accuracy did not improve from 0.95580
# Epoch 218/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0691 - accuracy: 0.9782 - val_loss: 0.6172 - val_accuracy: 0.8619
#
# Epoch 00218: val_accuracy did not improve from 0.95580
# Epoch 219/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0756 - accuracy: 0.9792 - val_loss: 3.7863 - val_accuracy: 0.5525
#
# Epoch 00219: val_accuracy did not improve from 0.95580
# Epoch 220/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0473 - accuracy: 0.9872 - val_loss: 0.9698 - val_accuracy: 0.8453
#
# Epoch 00220: val_accuracy did not improve from 0.95580
# Epoch 221/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0693 - accuracy: 0.9767 - val_loss: 0.7631 - val_accuracy: 0.8011
#
# Epoch 00221: val_accuracy did not improve from 0.95580
# Epoch 222/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0719 - accuracy: 0.9826 - val_loss: 1.3747 - val_accuracy: 0.8232
#
# Epoch 00222: val_accuracy did not improve from 0.95580
# Epoch 223/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0675 - accuracy: 0.9709 - val_loss: 1.1728 - val_accuracy: 0.7514
#
# Epoch 00223: val_accuracy did not improve from 0.95580
# Epoch 224/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1044 - accuracy: 0.9651 - val_loss: 7.4000 - val_accuracy: 0.4033
#
# Epoch 00224: val_accuracy did not improve from 0.95580
# Epoch 225/400
# 22/22 [==============================] - 2s 100ms/step - loss: 0.0620 - accuracy: 0.9836 - val_loss: 3.3078 - val_accuracy: 0.5856
#
# Epoch 00225: val_accuracy did not improve from 0.95580
# Epoch 226/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0267 - accuracy: 0.9901 - val_loss: 2.2365 - val_accuracy: 0.6188
#
# Epoch 00226: val_accuracy did not improve from 0.95580
# Epoch 227/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0451 - accuracy: 0.9884 - val_loss: 7.1150 - val_accuracy: 0.4420
#
# Epoch 00227: val_accuracy did not improve from 0.95580
# Epoch 228/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0751 - accuracy: 0.9747 - val_loss: 1.4338 - val_accuracy: 0.7624
#
# Epoch 00228: val_accuracy did not improve from 0.95580
# Epoch 229/400
# ...
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0270 - accuracy: 0.9898 - val_loss: 2.7155 - val_accuracy: 0.7624
#
# Epoch 00328: val_accuracy did not improve from 0.98895
# Epoch 329/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0259 - accuracy: 0.9901 - val_loss: 2.1697 - val_accuracy: 0.7845
#
# Epoch 00329: val_accuracy did not improve from 0.98895
# Epoch 330/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0439 - accuracy: 0.9898 - val_loss: 0.6481 - val_accuracy: 0.8674
#
# Epoch 00330: val_accuracy did not improve from 0.98895
# Epoch 331/400
# 22/22 [==============================] - 2s 101ms/step - loss: 0.0790 - accuracy: 0.9851 - val_loss: 0.8979 - val_accuracy: 0.8729
#
# Epoch 00331: val_accuracy did not improve from 0.98895
# Epoch 332/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0185 - accuracy: 0.9913 - val_loss: 4.9225 - val_accuracy: 0.5912
#
# Epoch 00332: val_accuracy did not improve from 0.98895
# Epoch 333/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0238 - accuracy: 0.9884 - val_loss: 6.8866 - val_accuracy: 0.5083
#
# Epoch 00333: val_accuracy did not improve from 0.98895
# Epoch 334/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0088 - accuracy: 0.9971 - val_loss: 0.1106 - val_accuracy: 0.9613
#
# Epoch 00334: val_accuracy did not improve from 0.98895
# Epoch 335/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0257 - accuracy: 0.9929 - val_loss: 0.3377 - val_accuracy: 0.9282
#
# Epoch 00335: val_accuracy did not improve from 0.98895
# Epoch 336/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0196 - accuracy: 0.9911 - val_loss: 0.6017 - val_accuracy: 0.8674
#
# Epoch 00336: val_accuracy did not improve from 0.98895
# Epoch 337/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0263 - accuracy: 0.9901 - val_loss: 0.6077 - val_accuracy: 0.8840
#
# Epoch 00337: val_accuracy did not improve from 0.98895
# Epoch 338/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0238 - accuracy: 0.9942 - val_loss: 0.7775 - val_accuracy: 0.8785
#
# Epoch 00338: val_accuracy did not improve from 0.98895
# Epoch 339/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0271 - accuracy: 0.9913 - val_loss: 0.8364 - val_accuracy: 0.8398
#
# Epoch 00339: val_accuracy did not improve from 0.98895
# Epoch 340/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0335 - accuracy: 0.9913 - val_loss: 10.0238 - val_accuracy: 0.3867
#
# Epoch 00340: val_accuracy did not improve from 0.98895
# Epoch 341/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0508 - accuracy: 0.9855 - val_loss: 5.7061 - val_accuracy: 0.3094
#
# Epoch 00341: val_accuracy did not improve from 0.98895
# Epoch 342/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0306 - accuracy: 0.9884 - val_loss: 1.6755 - val_accuracy: 0.8232
#
# Epoch 00342: val_accuracy did not improve from 0.98895
# Epoch 343/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0342 - accuracy: 0.9869 - val_loss: 1.3229 - val_accuracy: 0.8564
#
# Epoch 00343: val_accuracy did not improve from 0.98895
# Epoch 344/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0562 - accuracy: 0.9826 - val_loss: 0.3984 - val_accuracy: 0.9116
#
# Epoch 00344: val_accuracy did not improve from 0.98895
# Epoch 345/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0515 - accuracy: 0.9855 - val_loss: 0.7530 - val_accuracy: 0.8729
#
# Epoch 00345: val_accuracy did not improve from 0.98895
# Epoch 346/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0505 - accuracy: 0.9913 - val_loss: 5.5248 - val_accuracy: 0.4530
#
# Epoch 00346: val_accuracy did not improve from 0.98895
# Epoch 347/400
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0640 - accuracy: 0.9811 - val_loss: 2.8908 - val_accuracy: 0.6464
#
# Epoch 00347: val_accuracy did not improve from 0.98895
# Epoch 348/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0463 - accuracy: 0.9869 - val_loss: 4.5867 - val_accuracy: 0.6077
#
# Epoch 00348: val_accuracy did not improve from 0.98895
# Epoch 349/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0229 - accuracy: 0.9927 - val_loss: 3.1292 - val_accuracy: 0.7127
#
# Epoch 00349: val_accuracy did not improve from 0.98895
# Epoch 350/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0477 - accuracy: 0.9840 - val_loss: 2.6480 - val_accuracy: 0.6685
#
# Epoch 00350: val_accuracy did not improve from 0.98895
# Epoch 351/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0481 - accuracy: 0.9872 - val_loss: 1.3319 - val_accuracy: 0.7845
#
# Epoch 00351: val_accuracy did not improve from 0.98895
# Epoch 352/400
# 22/22 [==============================] - 2s 101ms/step - loss: 0.0430 - accuracy: 0.9866 - val_loss: 0.6046 - val_accuracy: 0.8729
#
# Epoch 00352: val_accuracy did not improve from 0.98895
# Epoch 353/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0505 - accuracy: 0.9855 - val_loss: 1.7643 - val_accuracy: 0.7348
#
# Epoch 00353: val_accuracy did not improve from 0.98895
# Epoch 354/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0270 - accuracy: 0.9869 - val_loss: 0.2391 - val_accuracy: 0.9392
#
# Epoch 00354: val_accuracy did not improve from 0.98895
# Epoch 355/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0281 - accuracy: 0.9898 - val_loss: 4.2566 - val_accuracy: 0.4751
#
# Epoch 00355: val_accuracy did not improve from 0.98895
# Epoch 356/400
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0107 - accuracy: 0.9972 - val_loss: 0.6923 - val_accuracy: 0.8619
#
# Epoch 00356: val_accuracy did not improve from 0.98895
# Epoch 357/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0410 - accuracy: 0.9913 - val_loss: 8.7482 - val_accuracy: 0.3536
#
# Epoch 00357: val_accuracy did not improve from 0.98895
# Epoch 358/400
# 22/22 [==============================] - 2s 102ms/step - loss: 0.0286 - accuracy: 0.9911 - val_loss: 0.1874 - val_accuracy: 0.9337
#
# Epoch 00358: val_accuracy did not improve from 0.98895
# Epoch 359/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0124 - accuracy: 0.9942 - val_loss: 4.1315 - val_accuracy: 0.7293
#
# Epoch 00359: val_accuracy did not improve from 0.98895
# Epoch 360/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0348 - accuracy: 0.9884 - val_loss: 0.9466 - val_accuracy: 0.8840
#
# Epoch 00360: val_accuracy did not improve from 0.98895
# Epoch 361/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.1830 - val_accuracy: 0.9558
#
# Epoch 00361: val_accuracy did not improve from 0.98895
# Epoch 362/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0513 - accuracy: 0.9884 - val_loss: 1.4977 - val_accuracy: 0.8011
#
# Epoch 00362: val_accuracy did not improve from 0.98895
# Epoch 363/400
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0534 - accuracy: 0.9869 - val_loss: 0.9281 - val_accuracy: 0.8619
#
# Epoch 00363: val_accuracy did not improve from 0.98895
# Epoch 364/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0499 - accuracy: 0.9855 - val_loss: 0.1888 - val_accuracy: 0.9448
#
# Epoch 00364: val_accuracy did not improve from 0.98895
# Epoch 365/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0723 - accuracy: 0.9840 - val_loss: 0.6020 - val_accuracy: 0.8895
#
# Epoch 00365: val_accuracy did not improve from 0.98895
# Epoch 366/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0326 - accuracy: 0.9927 - val_loss: 1.8134 - val_accuracy: 0.7238
#
# Epoch 00366: val_accuracy did not improve from 0.98895
# Epoch 367/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0366 - accuracy: 0.9869 - val_loss: 1.6693 - val_accuracy: 0.7403
#
# Epoch 00367: val_accuracy did not improve from 0.98895
# Epoch 368/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0210 - accuracy: 0.9927 - val_loss: 0.2362 - val_accuracy: 0.9558
#
# Epoch 00368: val_accuracy did not improve from 0.98895
# Epoch 369/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0321 - accuracy: 0.9913 - val_loss: 0.3532 - val_accuracy: 0.9171
#
# Epoch 00369: val_accuracy did not improve from 0.98895
# Epoch 370/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0357 - accuracy: 0.9898 - val_loss: 5.3933 - val_accuracy: 0.5193
#
# Epoch 00370: val_accuracy did not improve from 0.98895
# Epoch 371/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0704 - accuracy: 0.9738 - val_loss: 3.8125 - val_accuracy: 0.6022
#
# Epoch 00371: val_accuracy did not improve from 0.98895
# Epoch 372/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.1037 - accuracy: 0.9797 - val_loss: 6.9604 - val_accuracy: 0.4365
#
# Epoch 00372: val_accuracy did not improve from 0.98895
# Epoch 373/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0592 - accuracy: 0.9797 - val_loss: 11.8972 - val_accuracy: 0.3646
#
# Epoch 00373: val_accuracy did not improve from 0.98895
# Epoch 374/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.2170 - accuracy: 0.9549 - val_loss: 4.6215 - val_accuracy: 0.4917
#
# Epoch 00374: val_accuracy did not improve from 0.98895
# Epoch 375/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0887 - accuracy: 0.9759 - val_loss: 8.4356 - val_accuracy: 0.4475
#
# Epoch 00375: val_accuracy did not improve from 0.98895
# Epoch 376/400
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0431 - accuracy: 0.9836 - val_loss: 6.1305 - val_accuracy: 0.5359
#
# Epoch 00376: val_accuracy did not improve from 0.98895
# Epoch 377/400
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0813 - accuracy: 0.9787 - val_loss: 1.6999 - val_accuracy: 0.6685
#
# Epoch 00377: val_accuracy did not improve from 0.98895
# Epoch 378/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0782 - accuracy: 0.9724 - val_loss: 1.1692 - val_accuracy: 0.8287
#
# Epoch 00378: val_accuracy did not improve from 0.98895
# Epoch 379/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.1022 - accuracy: 0.9732 - val_loss: 3.3806 - val_accuracy: 0.6022
#
# Epoch 00379: val_accuracy did not improve from 0.98895
# Epoch 380/400
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0666 - accuracy: 0.9872 - val_loss: 0.7162 - val_accuracy: 0.8785
#
# Epoch 00380: val_accuracy did not improve from 0.98895
# Epoch 381/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0114 - accuracy: 0.9970 - val_loss: 0.4832 - val_accuracy: 0.9061
#
# Epoch 00381: val_accuracy did not improve from 0.98895
# Epoch 382/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0273 - accuracy: 0.9886 - val_loss: 0.0681 - val_accuracy: 0.9834
#
# Epoch 00382: val_accuracy did not improve from 0.98895
# Epoch 383/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0140 - accuracy: 0.9971 - val_loss: 0.1672 - val_accuracy: 0.9613
#
# Epoch 00383: val_accuracy did not improve from 0.98895
# Epoch 384/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0260 - accuracy: 0.9898 - val_loss: 1.7408 - val_accuracy: 0.7182
#
# Epoch 00384: val_accuracy did not improve from 0.98895
# Epoch 385/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0577 - accuracy: 0.9855 - val_loss: 0.1111 - val_accuracy: 0.9834
#
# Epoch 00385: val_accuracy did not improve from 0.98895
# Epoch 386/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0322 - accuracy: 0.9898 - val_loss: 0.1198 - val_accuracy: 0.9834
#
# Epoch 00386: val_accuracy did not improve from 0.98895
# Epoch 387/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0354 - accuracy: 0.9869 - val_loss: 3.8284 - val_accuracy: 0.6354
#
# Epoch 00387: val_accuracy did not improve from 0.98895
# Epoch 388/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0977 - accuracy: 0.9732 - val_loss: 11.5260 - val_accuracy: 0.1878
#
# Epoch 00388: val_accuracy did not improve from 0.98895
# Epoch 389/400
# 22/22 [==============================] - 2s 111ms/step - loss: 0.0864 - accuracy: 0.9730 - val_loss: 1.3363 - val_accuracy: 0.8177
#
# Epoch 00389: val_accuracy did not improve from 0.98895
# Epoch 390/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0742 - accuracy: 0.9811 - val_loss: 1.1549 - val_accuracy: 0.8287
#
# Epoch 00390: val_accuracy did not improve from 0.98895
# Epoch 391/400
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0498 - accuracy: 0.9884 - val_loss: 8.7388 - val_accuracy: 0.5083
#
# Epoch 00391: val_accuracy did not improve from 0.98895
# Epoch 392/400
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0612 - accuracy: 0.9898 - val_loss: 2.7869 - val_accuracy: 0.7182
#
# Epoch 00392: val_accuracy did not improve from 0.98895
# Epoch 393/400
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0136 - accuracy: 0.9956 - val_loss: 0.4253 - val_accuracy: 0.9171
#
# Epoch 00393: val_accuracy did not improve from 0.98895
# Epoch 394/400
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0771 - accuracy: 0.9855 - val_loss: 0.8329 - val_accuracy: 0.8453
#
# Epoch 00394: val_accuracy did not improve from 0.98895
# Epoch 395/400
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0786 - accuracy: 0.9797 - val_loss: 0.3015 - val_accuracy: 0.9392
#
# Epoch 00395: val_accuracy did not improve from 0.98895
# Epoch 396/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0680 - accuracy: 0.9840 - val_loss: 3.6873 - val_accuracy: 0.5746
#
# Epoch 00396: val_accuracy did not improve from 0.98895
# Epoch 397/400
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0483 - accuracy: 0.9797 - val_loss: 0.4572 - val_accuracy: 0.9116
#
# Epoch 00397: val_accuracy did not improve from 0.98895
# Epoch 398/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0242 - accuracy: 0.9913 - val_loss: 0.5429 - val_accuracy: 0.8619
#
# Epoch 00398: val_accuracy did not improve from 0.98895
# Epoch 399/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0384 - accuracy: 0.9869 - val_loss: 8.1943 - val_accuracy: 0.4586
#
# Epoch 00399: val_accuracy did not improve from 0.98895
# Epoch 400/400
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0209 - accuracy: 0.9915 - val_loss: 1.9546 - val_accuracy: 0.7901
#
# Epoch 00400: val_accuracy did not improve from 0.98895
# [INFO] serializing network...
# [INFO] serializing label binarizer...
# [INFO] evaluating network...
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                           precision    recall  f1-score   support
#
#         Cluster porosity       0.91      0.77      0.83        13
#                No defect       1.00      1.00      1.00        21
#             cap undercut       0.41      0.88      0.56        17
# lack of root penetration       1.00      0.35      0.52        17
#       longitudinal crack       0.95      1.00      0.97        36
#      parallel slag lines       1.00      1.00      1.00        14
#            root undercut       0.57      0.73      0.64        11
#        silica inclusions       0.00      0.00      0.00        11
#                slag line       0.64      0.90      0.75        10
#         transverse crack       0.92      0.77      0.84        31
#
#                 accuracy                           0.79       181
#                macro avg       0.74      0.74      0.71       181
#             weighted avg       0.81      0.79      0.77       181
